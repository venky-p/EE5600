# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Generate line points
def line_gen(A,B):
  len =10
  x_AB = np.zeros((2,len))
  lam_1 = np.linspace(0,1,len)
  for i in range(len):
    temp1 = A + lam_1[i]*(B-A)
    x_AB[:,i]= temp1.T
  return x_AB

# %%
A = np.array([1,-2])
B = np.array([-1,0])
C = np.array([3,0])
D = np.array([0,-3])

# %%
#Generating all lines
x_AB = line_gen(A,B)
x_CD = line_gen(C,D)


#Plotting all lines
plt.plot(x_AB[0,:],x_AB[1,:],label='$(1  1)x=-1$')
plt.plot(x_CD[0,:],x_CD[1,:],label='$(1 -1)x=3$')


plt.plot(A[0], A[1], 'o')
plt.text(A[0] * (1+0.025), A[1]*(1), '(1,-2)')
plt.plot(B[0], B[1], 'o')
plt.text(B[0] * (1+0.025), B[1]*(1) , '(-1,0)')
plt.plot(0, -1, 'o')
plt.text(0 * (1+0.025), (-1)*(1) , '(0,-1)')
plt.plot(C[0], C[1], 'o')
plt.text(C[0] * (1+0.07), C[1]*(1) , '(3,0)')
plt.plot(D[0], D[1], 'o')
plt.text(D[0] * (1+0.07), D[1]*(1) , '(0,-3)')

plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend(loc='best')
plt.grid()
plt.savefig('Assignment_2.pdf')
plt.show()
